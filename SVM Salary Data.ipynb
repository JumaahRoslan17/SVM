# %%
import pandas as pd
import numpy as np
import seaborn as sns
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-79f6ba03-323b-457c-8588-f55fadde126d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-79f6ba03-323b-457c-8588-f55fadde126d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving SalaryData_Test (3).csv to SalaryData_Test (3) (1).csv
# Saving SalaryData_Train (3).csv to SalaryData_Train (3) (1).csv

# %%
SD_train=pd.read_csv('SalaryData_Train (3) (1).csv')
SD_test=pd.read_csv('SalaryData_Test (3) (1).csv')

# %%
SD_train.columns
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
SD_test.columns
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
string_col=['workclass','education','maritalstatus','occupation','relationship','race','sex','native']

# %%
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
for i in string_col:
  SD_train[i]=label_encoder.fit_transform(SD_train[i])
  SD_test[i]=label_encoder.fit_transform(SD_test[i])

# %%
train_x=SD_train.iloc[0:500,0:13]
train_y=SD_train.iloc[0:500,13]
test_x=SD_test.iloc[0:300,0:13]
test_y=SD_test.iloc[0:300,13]

# %% [markdown]
# SVM Classification

# %%
from sklearn.svm import SVC

# %%
#linear
model_linear=SVC(kernel= 'linear')
model_linear.fit(train_x,train_y)
train_pred_lin=model_linear.predict(train_x)
test_pred_lin=model_linear.predict(test_x)
train_lin_acc=np.mean(train_pred_lin==train_y)
test_lin_acc=np.mean(test_pred_lin==test_y)

# %%
train_lin_acc
# Out:
# 0.818

# %%
test_lin_acc
# Out:
# 0.8166666666666667

# %%
#poly
model_poly=SVC(kernel= 'poly')
model_poly.fit(train_x,train_y)
train_pred_poly=model_poly.predict(train_x)
test_pred_poly=model_poly.predict(test_x)
train_poly_acc=np.mean(train_pred_poly==train_y)
test_poly_acc=np.mean(test_pred_poly==test_y)

# %%
train_poly_acc
# Out:
# 0.812

# %%
test_poly_acc
# Out:
# 0.8033333333333333

# %%
#rbf
model_rbf=SVC(kernel= 'rbf')
model_rbf.fit(train_x,train_y)
train_pred_rbf=model_rbf.predict(train_x)
test_pred_rbf=model_rbf.predict(test_x)
train_rbf_acc=np.mean(train_pred_rbf==train_y)
test_rbf_acc=np.mean(test_pred_rbf==test_y)

# %%
train_rbf_acc
# Out:
# 0.812

# %%
test_rbf_acc
# Out:
# 0.8033333333333333
